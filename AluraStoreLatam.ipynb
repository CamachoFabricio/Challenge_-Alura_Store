# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %% [markdown]
# #1. Análisis de facturación

# %%
facturacion = tienda['Precio'].sum()
print(f'Ingreso total tienda 1: {facturacion}')

facturacion_2 = tienda2['Precio'].sum()
print(f'Ingreso total tienda 2: {facturacion_2}')

facturacion_3 = tienda3['Precio'].sum()
print(f'Ingreso total tienda 3: {facturacion_3}')

facturacion_4 = tienda4['Precio'].sum()
print(f'Ingreso total tienda 4: {facturacion_4}')
# Out:
# Ingreso total tienda 1: 1150880400.0
# Ingreso total tienda 2: 1116343500.0
# Ingreso total tienda 3: 1098019600.0
# Ingreso total tienda 4: 1038375700.0

# %%
total_ingresos = [facturacion, facturacion_2, facturacion_3, facturacion_4]
tiendas = ['tienda', 'tienda2', 'tienda3', 'tienda4']
color = ['yellow', 'green', 'blue', 'orange']

plt.pie(total_ingresos, labels=tiendas, autopct='%1.1f%%', colors=color, startangle=90)

plt.title('Ingresos Por Tienda')

plt.show()

# %% [markdown]
# # 2. Ventas por categoría

# %%
categoria = tienda.groupby('Categoría del Producto')['Producto'].count().sort_values(ascending=False)
print(f'Cantidad de productos vendidos por categoría tienda 1:\n{categoria}\n')

categoria_2 = tienda2.groupby('Categoría del Producto')['Producto'].count().sort_values(ascending=False)
print(f'Cantidad de productos vendidos por categoría tienda 2:\n{categoria_2}\n')

categoria_3 = tienda3.groupby('Categoría del Producto')['Producto'].count().sort_values(ascending=False)
print(f'Cantidad de productos vendidos por categoría tienda 3:\n{categoria_3}\n')

categoria_4 = tienda4.groupby('Categoría del Producto')['Producto'].count().sort_values(ascending=False)
print(f'Cantidad de productos vendidos por categoría tienda 4:\n{categoria_4}\n')

# %%
plt.figure(figsize=(8, 4))
categoria.plot(kind='bar', color='lightcoral')
plt.title('Productos vendidos por categoría - Tienda 1')
plt.xlabel('Categoría del Producto')
plt.ylabel('Cantidad de productos vendidos')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()


plt.figure(figsize=(8, 4))
categoria_2.plot(kind='bar', color='mediumseagreen')
plt.title('Productos vendidos por categoría - Tienda 2')
plt.xlabel('Categoría del Producto')
plt.ylabel('Cantidad de productos vendidos')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()


plt.figure(figsize=(8, 4))
categoria_3.plot(kind='bar', color='lightcoral')
plt.title('Productos vendidos por categoría - Tienda 3')
plt.xlabel('Categoría del Producto')
plt.ylabel('Cantidad de productos vendidos')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()



plt.figure(figsize=(8, 4))
categoria_4.plot(kind='bar', color='mediumseagreen')
plt.title('Productos vendidos por categoría - Tienda 4')
plt.xlabel('Categoría del Producto')
plt.ylabel('Cantidad de productos vendidos')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()

# %%
comparacion = pd.DataFrame({
    'Tienda 1': categoria,
    'Tienda 2': categoria_2,
    'Tienda 3': categoria_3,
    'Tienda 4': categoria_4
}).fillna(0)

comparacion.plot(kind='bar', figsize=(10, 5), colormap='Set2')
plt.title('Ventas Por Tienda y Categoria')
plt.xlabel('Categoría del Producto')
plt.ylabel('Cantidad de productos vendidos')
plt.xticks(rotation=45)
plt.legend(title='Tienda')
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
promedio = tienda['Calificación'].mean()
print(f'Calificación promedio de los clientes de la tienda 1: {promedio}')

promedio_2 = tienda2['Calificación'].mean()
print(f'Calificación promedio de los clientes de la tienda 2: {promedio_2}')

promedio_3 = tienda3['Calificación'].mean()
print(f'Calificación promedio de los clientes de la tienda 3: {promedio_3}')

promedio_4 = tienda4['Calificación'].mean()
print(f'Calificación promedio de los clientes de la tienda 4: {promedio_4}')
# Out:
# Calificación promedio de los clientes de la tienda 1: 3.976685036032217
# Calificación promedio de los clientes de la tienda 2: 4.037303942348453
# Calificación promedio de los clientes de la tienda 3: 4.048325561678677
# Calificación promedio de los clientes de la tienda 4: 3.9957591178965224

# %%
tiendas = ['tienda', 'tienda2', 'tienda3', 'tienda4']
calificacion_clietes = [promedio, promedio_2, promedio_3, promedio_4]

plt.figure(figsize=(8, 5))
plt.bar(tiendas, total_ingresos, color='skyblue')
plt.title('Calificación Promedio De La Tienda')
plt.xlabel('Tiendas')
plt.ylabel('Calificación')
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()

plt.show()

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
producto = tienda['Producto'].value_counts()

print("\033[1mTop 5 productos más vendidos Tienda 1:\033[0m")

for i, (nombre_producto, cantidad_vendida) in enumerate(producto.items(), start=1):
    if i > 5:
        break
    print(f"{i}. {nombre_producto} - {cantidad_vendida}")


print("\033[1mTop 5 productos menos vendidos Tienda 1:\033[0m")

for i, (nombre_producto, cantidad_vendida) in enumerate(producto.tail(5).items(), start=1):
    if i > 5:
        break
    print(f"{i}. {nombre_producto} - {cantidad_vendida}")
# Out:
# Top 5 productos más vendidos Tienda 1:
# 1. Microondas - 60
# 2. TV LED UHD 4K - 60
# 3. Armario - 60
# 4. Secadora de ropa - 58
# 5. Mesa de noche - 56
# Top 5 productos menos vendidos Tienda 1:
# 1. Ciencia de datos con Python - 39
# 2. Pandereta - 36
# 3. Olla de presión - 35
# 4. Auriculares con micrófono - 33
# 5. Celular ABXY - 33

# %%
producto_2 = tienda2['Producto'].value_counts()

print("\033[1mTop 5 productos más vendidos Tienda 2:\033[0m")

for i, (nombre_producto, cantidad_vendida) in enumerate(producto_2.items(), start=1):
    if i > 5:
        break
    print(f"{i}. {nombre_producto} - {cantidad_vendida}")


print("\033[1mTop 5 productos menos vendidos Tienda 2:\033[0m")

for i, (nombre_producto, cantidad_vendida) in enumerate(producto_2.tail(5).items(), start=1):
    if i > 5:
        break
    print(f"{i}. {nombre_producto} - {cantidad_vendida}")
# Out:
# Top 5 productos más vendidos Tienda 2:
# 1. Iniciando en programación - 65
# 2. Microondas - 62
# 3. Batería - 61
# 4. Guitarra acústica - 58
# 5. Pandereta - 58
# Top 5 productos menos vendidos Tienda 2:
# 1. Auriculares - 37
# 2. Sillón - 35
# 3. Mesa de comedor - 34
# 4. Impresora - 34
# 5. Juego de mesa - 32

# %%
producto_3 = tienda3['Producto'].value_counts()

print("\033[1mTop 5 productos más vendidos Tienda 3:\033[0m")

for i, (nombre_producto, cantidad_vendida) in enumerate(producto_3.items(), start=1):
    if i > 5:
        break
    print(f"{i}. {nombre_producto} - {cantidad_vendida}")


print("\033[1mTop 5 productos menos vendidos Tienda 1:\033[0m")

for i, (nombre_producto, cantidad_vendida) in enumerate(producto_3.tail(5).items(), start=1):
    if i > 5:
        break
    print(f"{i}. {nombre_producto} - {cantidad_vendida}")
# Out:
# Top 5 productos más vendidos Tienda 3:
# 1. Kit de bancas - 57
# 2. Mesa de comedor - 56
# 3. Cama king - 56
# 4. Set de ollas - 55
# 5. Mesa de noche - 55
# Top 5 productos menos vendidos Tienda 1:
# 1. Guitarra eléctrica - 38
# 2. Set de vasos - 36
# 3. Mochila - 36
# 4. Microondas - 36
# 5. Bloques de construcción - 35

# %%
producto_4 = tienda4['Producto'].value_counts()

print("\033[1mTop 5 productos más vendidos Tienda 4:\033[0m")

for i, (nombre_producto, cantidad_vendida) in enumerate(producto_4.items(), start=1):
    if i > 5:
        break
    print(f"{i}. {nombre_producto} - {cantidad_vendida}")


print("\033[1mTop 5 productos menos vendidos Tienda 4:\033[0m")

for i, (nombre_producto, cantidad_vendida) in enumerate(producto_4.tail(5).items(), start=1):
    if i > 5:
        break
    print(f"{i}. {nombre_producto} - {cantidad_vendida}")
# Out:
# Top 5 productos más vendidos Tienda 4:
# 1. Cama box - 62
# 2. Cubertería - 59
# 3. Dashboards con Power BI - 56
# 4. Cama king - 56
# 5. Carrito de control remoto - 55
# Top 5 productos menos vendidos Tienda 4:
# 1. Refrigerador - 38
# 2. Ciencia de datos con Python - 38
# 3. Guitarra acústica - 37
# 4. Armario - 34
# 5. Guitarra eléctrica - 33

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
envio_prom = tienda['Costo de envío'].mean()
print(f'Costo de envío promedio tienda 1: {envio_prom}')

envio_prom_2 = tienda2['Costo de envío'].mean()
print(f'Costo de envío promedio tienda 2: {envio_prom_2}')

envio_prom_3 = tienda3['Costo de envío'].mean()
print(f'Costo de envío promedio tienda 3: {envio_prom_3}')

envio_prom_4 = tienda4['Costo de envío'].mean()
print(f'Costo de envío promedio tienda 4: {envio_prom_4}')
# Out:
# Costo de envío promedio tienda 1: 26018.60958033065
# Costo de envío promedio tienda 2: 25216.235693090293
# Costo de envío promedio tienda 3: 24805.680373039424
# Costo de envío promedio tienda 4: 23459.457167090754

# %%
tiendas = ['tienda', 'tienda2', 'tienda3', 'tienda4']
envio_promedio = [envio_prom, envio_prom_2, envio_prom_3, envio_prom_4]

plt.figure(figsize=(8, 5))
plt.barh(tiendas, envio_promedio, color='green')
plt.title('Envío Promedio Por Tienda')
plt.xlabel('Costo')
plt.ylabel('Tiendas')
plt.tight_layout()

plt.show()

# %% [markdown]
# # Informe final

# %% [markdown]
# **Introducción:**
# Este análisis fue hecho para determinar que tienda debe ser vendida por el sr. Juan tomando como base los ingresos generados, las calificaciones de los clientes, el coste de los envíos y por los productos más y menos vendidos de cada una de las 4 tiendas.
#
# **Desarrollo:**
# Lo primero que hice fue obtener los resultados de los ingresos totales por cada tienda en este paso genere un gráfico de pie para ver cómo se distribuyeron los ingresos por tienda, después saque las ventas por categoría y tienda, para la visualización agrupe las tiendas por categorías y genere un gráfico de barras para ver la cantidad de productos vendidos en cada tienda según la categoría, el siguiente paso fue obtener la calificación promedio de los clientes a cada tienda el gráfico que utilice fue el de barras para ver que tiendas tienen la mayor y menor calificación, después obtuvimos los productos más y menos vendidos por tienda y al final sacamos el promedio del costo de envío por tienda para este análisis hice una visualización char.
# Tanto los resultados de los análisis y visualizaciones están arriba de este informe.
#
# **Conclusión:**
# En base al análisis y visualizaciones hechos para identificar que tienda debe vender el sr. juan llegue a la conclusión que la tienda que debe ser vendida es la tienda 4.
#
# **Justificación:**
# Llegue a esa conclusión por que la tienda 4 es la que menos ingresos tiene además de que la calificación promedio de los clientes la ponen como la tienda más baja en ese rubro, llama la atención que en la parte de envíos sea la que menos gasta pero es porque también es la que menos vende por ello el promedio de costo de envió es menor a las otras 3 tiendas.
